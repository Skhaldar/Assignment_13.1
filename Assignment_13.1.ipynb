# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import sqlite3 as db

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
data1 = pd.read_csv(url, names=['Age','workclass','fnlwgt','education','education_num','marital_status','occupation','relationship','race','sex','capital_gain','capital_loss','hours_per_week','native_country','label'])
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# Age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# label             32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 2.6+ MB

# %%
data1.head()
# Out:
#    Age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country   label
# 0          2174             0              40   United-States   <=50K
# ...

# %%
data1.head(10)
# Out:
#    Age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital_status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
from pandasql import sqldf

# %%
#define the global function, as managing local and global environment might be confusing at times
pysqldf = lambda q: sqldf(q, globals())

# %%
pysqldf
# Out:
# <function __main__.<lambda>(q)>

# %%
from pandasql import sqldf

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',names=['Age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','>50K, <=50K'])

# %%
df.head(10)
# Out:
#    Age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df.describe()
# Out:
#                 Age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby("workclass").mean()
# Out:
#                          Age         fnlwgt  education-num  capital-gain  \
# workclass
#  ?                 40.960240  188516.338235       9.260349    606.795752
#  Federal-gov       42.590625  185221.243750      10.973958    833.232292
#  Local-gov         41.751075  188639.712852      11.042045    880.202580
#  Never-worked      20.571429  225989.571429       7.428571      0.000000
#  Private           36.797585  192764.114734       9.879714    889.217792
#  Self-emp-inc      46.017025  175981.344086      11.137097   4875.693548
#  Self-emp-not-inc  44.969697  175608.641480      10.226289   1886.061787
#  State-gov         39.436055  184136.613251      11.375963    701.699538
#  Without-pay       47.785714  174267.500000       9.071429    487.857143
#
#                    capital-loss  hours-per-week
# workclass
#  ?                    60.760349       31.919390
#  Federal-gov         112.268750       41.379167
#  Local-gov           109.854276       40.982800
# ...

# %%
df.groupby("education-num").sum()
# Out:
#                   Age      fnlwgt  capital-gain  capital-loss  hours-per-week
# education-num
# 1                2181    12030358         45818          3391            1869
# 2                7752    40202904         21147          8119            6427
# 3               14281    77405295         58615         22728           12953
# 4               31296   121499145        151125         42422           25431
# 5               21105   104077324        175834         14905           19555
# 6               34922   183644690        377468         53037           34570
# 7               38018   229040491        252740         58843           39863
# 8               13856    86209221        123010         14002           15493
# 9              409271  1990346306       6056978        739970          426082
# 10             260699  1376124647       4366027        522306          283272
# 11              53281   251435575        988201        100547           57506
# ...

# %%
df.groupby("occupation").sum()
# Out:
#                        Age     fnlwgt  education-num  capital-gain  \
# occupation
#  ?                   75347  347697924          17054       1114077
#  Adm-clerical       139356  724003604          38128       1869750
#  Armed-Forces          272    1938833             91             0
#  Craft-repair       159990  787551526          37345       2662353
#  Exec-managerial    171460  749827375          46552       9200435
#  Farming-fishing     40964  169169035           8557        586188
#  Handlers-cleaners   44067  280015679          11659        352875
#  Machine-op-inspct   75506  390471837          16992        658036
#  Other-service      115159  621464850          28929        630339
#  Priv-house-serv      6217   29965021           1097         41698
#  Prof-specialty     167743  767127979          53427      11288536
#  Protective-serv     25281  131123930           6610        459556
#  Sales              136342  696733506          37594       4817377
# ...

# %%
df.groupby("relationship").sum()
# Out:
#                     Age      fnlwgt  education-num  capital-gain  \
# relationship
#  Husband         578099  2468078661         136237      23682256
#  Not-in-family   318464  1587349560          85671       6173333
#  Other-relative   32534   201163685           8620        274283
#  Own-child       125828   979012972          48076        788862
#  Unmarried       138853   658628486          33227       1568037
#  Wife             62479   285140028          16406       2602553
#
#                  capital-loss  hours-per-week
# relationship
#  Husband              1638055          582077
#  Not-in-family         626120          337147
#  Other-relative         50357           36303
#  Own-child             200246          168609
#  Unmarried             142888          134749
#  Wife                  185034           57799

# %%
male_passengers = df.loc[df.sex == 'Male',:]
print('Number of male passengers : {0}'.format(len(male_passengers)))
# Out:
# Number of male passengers : 0

# %%
abc = df.loc[(df["marital-status"]=="Married-civ-spouse") & (df["education"]=="Masters") & (df["workclass"]=="Private"),:]
print (abc)
# Out:
# Empty DataFrame
# Columns: [Age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, >50K, <=50K]
# Index: []

# %%
df.groupby(['marital-status'])['education','workclass'].sum()
# Out:
#                                                                 education  \
# marital-status
#  Divorced                HS-grad Masters HS-grad HS-grad Bachelors Mas...
#  Married-AF-spouse       HS-grad Assoc-acdm HS-grad HS-grad Some-colle...
#  Married-civ-spouse      Bachelors 11th Bachelors Masters HS-grad Bach...
#  Married-spouse-absent   9th 7th-8th HS-grad Assoc-acdm HS-grad Bachel...
#  Never-married           Bachelors Masters Bachelors Assoc-acdm HS-gra...
#  Separated               HS-grad HS-grad Bachelors Some-college Bachel...
#  Widowed                 HS-grad Masters Assoc-voc Assoc-voc 10th Asso...
#
#                                                                 workclass
# marital-status
#  Divorced                Private Self-emp-not-inc Private Private Priv...
#  Married-AF-spouse       Private ? Federal-gov Private Private Self-em...
#  Married-civ-spouse      Self-emp-not-inc Private Private Private Self...
# ...

# %%
df.groupby("workclass")["Age"].mean()
# Out:
# workclass
#  ?                   40.960240
#  Federal-gov         42.590625
#  Local-gov           41.751075
#  Never-worked        20.571429
#  Private             36.797585
#  Self-emp-inc        46.017025
#  Self-emp-not-inc    44.969697
#  State-gov           39.436055
#  Without-pay         47.785714
# Name: Age, dtype: float64

# %%
df.groupby("workclass")["Age"].min()
# Out:
# workclass
#  ?                   17
#  Federal-gov         17
#  Local-gov           17
#  Never-worked        17
#  Private             17
#  Self-emp-inc        17
#  Self-emp-not-inc    17
#  State-gov           17
#  Without-pay         19
# Name: Age, dtype: int64

# %%
df.groupby("workclass")["Age"].max()
# Out:
# workclass
#  ?                   90
#  Federal-gov         90
#  Local-gov           90
#  Never-worked        30
#  Private             90
#  Self-emp-inc        84
#  Self-emp-not-inc    90
#  State-gov           81
#  Without-pay         72
# Name: Age, dtype: int64

# %%
df[['native-country','Age']]
# Out:
#        native-country  Age
# 0       United-States   39
# 1       United-States   50
# 2       United-States   38
# 3       United-States   53
# 4                Cuba   28
# 5       United-States   37
# 6             Jamaica   49
# 7       United-States   52
# 8       United-States   31
# 9       United-States   42
# 10      United-States   37
# 11              India   30
# 12      United-States   23
# 13      United-States   32
# 14                  ?   40
# 15             Mexico   34
# 16      United-States   25
# 17      United-States   32
# 18      United-States   38
# 19      United-States   43
# 20      United-States   40
# 21      United-States   54
# 22      United-States   35
# 23      United-States   43
# 24      United-States   59
# 25      United-States   56
# 26      United-States   19
# 27              South   54
# 28      United-States   39
# 29      United-States   49
# ...               ...  ...
# 32531   United-States   30
# 32532   United-States   34
# ...
